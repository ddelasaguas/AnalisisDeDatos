# %%
import pandas as pd

df = pd.read_csv('ArchivoCSV\supply_chain_data.csv', sep=';', encoding='latin1')
#print(df)

#df.head(20)
# df.describe()
# df.tail()
df3 = display(df[["Precio","Tipo de producto"]])


# df.head(10)
# print(f"plazo de fabricacion promedio: {df['Plazo de fabricación'].mean()}")
# print(f"Plazo de entrega mediana: {df['Plazo de entrega'].max()}")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\F501\AppData\Local\Temp\ipykernel_19792\1931912088.py:3: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('ArchivoCSV\supply_chain_data.csv', sep=';', encoding='latin1')
#        Precio       Tipo de producto
# 0   69.808006    cuidado del cabello
# 1   14.843523  protección de la piel
# 2   11.319683    cuidado del cabello
# 3   61.163343  protección de la piel
# 4    4.805496  protección de la piel
# ..        ...                    ...
# 95  77.903927    cuidado del cabello
# 96  24.423131   productos cosméticos
# 97   3.526111    cuidado del cabello
# 98  19.754605  protección de la piel
# 99  68.517833    cuidado del cabello
#
# [100 rows x 2 columns]
